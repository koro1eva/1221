# %% [markdown]
# # 3 раздел

# %% [markdown]
# ## Задание 1.1

# %%
import matplotlib.pyplot as plt
import numpy as np
x_data = np.linspace(0, 10, 1000)
y_data = np.sin(x_data)
plt.plot(x_data, y_data)
plt.xlabel('x_data')
plt.ylabel('y_data')
plt.title('function sin(x)')
plt.grid( linewidth=0.8,linestyle='--')

plt.plot(x_data, y_data, linewidth ='1', color='r')

plt.xlabel('x_data')
plt.ylabel('y_data')
plt.title('function sin(x)')
plt.show()

# %% [markdown]
# ## Задание 1.2

# %%
import matplotlib.pyplot as plt
import numpy as np
x_data = np.linspace(0, 20, 100)
y_data = np.cos(x_data)

fig = plt.figure()
ax = plt.axes()


ax.grid( linewidth=0.8, linestyle='--')

s=[1]
plt.scatter(x_data, y_data,marker= 's' , color='b')

plt.xlabel('x_data')
plt.ylabel('y_data')
plt.title('function cos(x)')
plt.legend(['cos(x)'])
plt.show()

# %% [markdown]
# ## Задание 1.3

# %%
import matplotlib.pyplot as plt
import random

a= [random.randint(0, 100) for x in range(100)]

b= [random.randint(0, 100) for x in range(100)]

s= [random.randint(0, 100) for x in range(100)]

fig, (ax1, ax2,ax3) = plt.subplots(nrows=1, ncols=3)

ax1.hist(a, bins = 10, color='b')
ax2.hist(b, bins = 30, color='r')
ax3.hist(s, bins = 50, color='r')
plt.show()
